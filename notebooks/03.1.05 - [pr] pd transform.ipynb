# %%
import numpy as np
import pandas as pd
pd.set_option("display.float_format", "{:,.2f}".format)
pd.set_option("display.max_columns", None)
from classes import Paths

# %%
paths = Paths()
path = paths.transform_practice_sample_rides
df = pd.read_csv(path)
df.head()
# Out:
#        car_id ride_id     user_id  rating  ride_cost  true_car_ride_count  \
# 0  D17587481H     E1V  Q20675647n    1.96        282                    3
# 1  w13176062d     V1h  O11803938a    4.45        308                    4
# 2  s-2202835E     B1g  u20234217o    2.76        525                    4
# 3  H-1213278K     i1U  c19828320U    7.12       6154                    5
# 4  H-2108091L     j1Z  l90945335K    1.68        539                    4
#
#    true_user_rating_max  true_user_ride_cost_mean
# 0                  1.96                    282.00
# 1                  4.45                    308.00
# 2                  2.76                    525.00
# 3                  7.12                  6,154.00
# 4                  1.68                    539.00

# %% [markdown]
# ## 1. Common way of getting new aggregated feature without loosing raw data:
# **`groupby()` + `agg()` + `merge()`**

# %% [markdown]
# <img src="../imgs/03.1.05_1.png" width=800>

# %%
df_gr = df.groupby(by=["car_id"], as_index=False).agg(rating_mean = ("rating", "mean"))
display(df_gr.head())
df = df.merge(df_gr
            , on="car_id"
            , how="left"
            # , suffixes=["_left", "_right"]
            )
df
# Out:
#        car_id  rating_mean
# 0  B-6025126p         4.47
# 1  D17587481H         5.47
# 2  D28621238x         5.54
# 3  H-1213278K         4.18
# 4  H-2108091L         3.35
#         car_id ride_id     user_id  rating  ride_cost  true_car_ride_count  \
# 0   D17587481H     E1V  Q20675647n    1.96        282                    3
# 1   w13176062d     V1h  O11803938a    4.45        308                    4
# 2   s-2202835E     B1g  u20234217o    2.76        525                    4
# 3   H-1213278K     i1U  c19828320U    7.12       6154                    5
# 4   H-2108091L     j1Z  l90945335K    1.68        539                    4
# ..         ...     ...         ...     ...        ...                  ...
# 95  I-1538597J     E1u  s62773754W    9.80        115                    2
# 96  g21645452f     r1J  a28773047v    4.26        387                    3
# 97  s20690018N     z1A  m35202170I    2.75        155                    2
# 98  v11386552i     z1v  b62669559O    0.88     123261                    2
# 99  W-1942072H     q1N  H27099396J    5.74     441273                    2
#
#     true_user_rating_max  true_user_ride_cost_mean  rating_mean
# 0                   1.96                    282.00         5.47
# 1                   4.45                    308.00         3.91
# 2                   2.76                    525.00         2.27
# 3                   7.12                  6,154.00         4.18
# 4                   1.68                    539.00         3.35
# ..                   ...                       ...          ...
# 95                  9.80                    115.00         5.08
# 96                  4.26                    387.00         2.48
# 97                  2.75                    155.00         3.38
# 98                  0.88                123,261.00         3.17
# 99                  5.74                441,273.00         5.71
#
# [100 rows x 9 columns]

# %% [markdown]
# ## 2. New aggregated feature using single line
# **`groupby()` + `transform()`**

# %%
df['rating_mean'] = df.groupby(by=['car_id'])['rating'].transform('mean')
df.head(10)
# Out:
#        car_id ride_id     user_id  rating  ride_cost  true_car_ride_count  \
# 0  D17587481H     E1V  Q20675647n    1.96        282                    3
# 1  w13176062d     V1h  O11803938a    4.45        308                    4
# 2  s-2202835E     B1g  u20234217o    2.76        525                    4
# 3  H-1213278K     i1U  c19828320U    7.12       6154                    5
# 4  H-2108091L     j1Z  l90945335K    1.68        539                    4
# 5  w13176062d     Z1u  B22315336q    4.22       5065                    4
# 6  P52156891U     p1H  z20298839s    7.29      78515                    1
# 7  q-1536726P     g1M  m20570785V    1.99        806                    3
# 8  g-1247997Z     o1U  q12768126R    4.52        974                    4
# 9  W-1942072H     O1Z  D16051881Q    5.68        204                    2
#
#    true_user_rating_max  true_user_ride_cost_mean  rating_mean
# 0                  1.96                    282.00         5.47
# 1                  4.45                    308.00         3.91
# 2                  2.76                    525.00         2.27
# 3                  7.12                  6,154.00         4.18
# 4                  1.68                    539.00         3.35
# 5                  4.22                  5,065.00         3.91
# 6                  7.29                 78,515.00         7.29
# 7                  1.99                    806.00         3.03
# 8                  4.52                    974.00         4.62
# 9                  5.68                    204.00         5.71

# %% [markdown]
# **The main feature of the transform function is the ability to preserve the position of the original index/dataset. This is a unique feature of `transform`. Below is a visual explanation of how this function works:**
#
# <img src="../imgs/03.1.05_2.png" width=800>
